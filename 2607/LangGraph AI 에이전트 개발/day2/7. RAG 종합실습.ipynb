# %% [markdown]
# # **RAG 종합실습**
#
# * QA 챗봇 모델 만들기
#     * Vector DB에 데이터 추가하기
#     * Retriever, LLM를 연결하기

# %% [markdown]
# ## **1. 환경준비**

# %% [markdown]
# ### (1) 구글 드라이브

# %% [markdown]
# * 구글 드라이브 폴더 생성
#     * 새 폴더 `ai_agent`를 생성
#     * 제공 받은 파일을 업로드

# %% [markdown]
# * 구글 드라이브 연결

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### (2) 라이브러리

# %% [markdown]
# * 필요한 라이브러리 설치

# %%
# !pip install -q langchain-openai langchain-community chromadb langchain-tavily tavily-python pymupdf langchain-chroma

# %% [markdown]
# * 라이브러리 Import

# %%
import os
import pandas as pd
import ast

from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage
from langchain_core.tools import tool
from langchain_chroma import Chroma
from langchain_community.document_loaders import CSVLoader
from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.prebuilt import ToolNode, tools_condition
from langchain_tavily import TavilySearch

# %% [markdown]
# ### (3) OpenAI API Key 등록
# * 환경변수로 key 등록

# %%
def load_api_keys(filepath="api_key.txt"):
    with open(filepath, "r") as f:
        for line in f:
            line = line.strip()
            if line and "=" in line:
                key, value = line.split("=", 1)
                os.environ[key.strip()] = value.strip()

path = '/content/drive/MyDrive/ai_agent/'

# API 키 로드 및 환경변수 설정
load_api_keys(path + 'api_key.txt')

# %%
print(os.environ['OPENAI_API_KEY'][:40])
print(os.environ['TAVILY_API_KEY'][:40])

# %% [markdown]
# ## **2. Vector DB 만들기**

# %% [markdown]
# ### (1) 데이터 로딩
# * 제공한 csv 파일의 구조를 그대로 이용
# * csv 로더로 로딩하기

# %%
# CSV 파일 로딩

# %% [markdown]
# ### (2) 임베딩 & 저장
# * Embedding 모델 : text-embedding-3-small
# * DB 경로 : ./sc_faq

# %% [markdown]
# ## **3. 1단계**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) 도구 준비

# %%
# ① FAQ 검색 도구


# ② 웹 검색 도구


# 도구 목록

# %% [markdown]
# ### (2) State 및 LLM 정의

# %%
# State 정의


# 답변 LLM (도구 바인딩)

# %% [markdown]
# ### (3) 노드 준비

# %%
# ① 답변 생성 노드

# %% [markdown]
# ### (4) 그래프

# %%
from langgraph.checkpoint.memory import MemorySaver  # MemorySaver 모듈 가져오기

# %% [markdown]
# ## **4. 2단계**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### (1) State 및 LLM 정의

# %%
# State 정의


# 답변 LLM (도구 바인딩)

# 피드백 LLM

# %% [markdown]
# ### (2) 노드 준비

# %%
# ① 답변 생성 노드

# %%
# ② 적절성 피드백 노드

# %% [markdown]
# ### (3) 그래프
